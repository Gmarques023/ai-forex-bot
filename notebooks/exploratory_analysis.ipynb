# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Path para o arquivo combinado
data_path = '../src/data/raw/GBPUSD/M1/2024/GBPUSD_M1_2024.csv'

# Carregar os dados
df = pd.read_csv(data_path, header=None)  # CSV não tem cabeçalho

# Inspecionar dados
# Ver as primeiras linhas do DataFrame
print(df.head())

# Informações do DataFrame
print(df.info())

# Estatisticas descritivas
print(df.describe())

# Converter a coluna de datas para o formato datetime
df['date'] = pd.to_datetime(df[0] + ' ' + df[1])  # As datas estão nas colunas '0' e '1'
df.set_index('date', inplace=True)

# Visualização de Dados
# Plotar os preços de fechamento
plt.figure(figsize=(14, 7))
plt.plot(df[3])  # O preço de fechamento está na coluna '2'
plt.title('Preço de fecho GBP/USD')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento')
plt.show()

# Análise de Correlação
# Matriz de correlação
correlation_matrix = df.corr()

# Plotar a matriz de correlação
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlação')
plt.show()
# Out:
#             0      1        2        3        4        5  6
# 0  2024.01.14  17:00  1.27373  1.27380  1.27372  1.27380  0
# 1  2024.01.14  17:01  1.27380  1.27380  1.27380  1.27380  0
# 2  2024.01.14  17:04  1.27380  1.27380  1.27380  1.27380  0
# 3  2024.01.14  17:05  1.27380  1.27445  1.27380  1.27445  0
# 4  2024.01.14  17:06  1.27445  1.27452  1.27445  1.27445  0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163083 entries, 0 to 163082
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   0       163083 non-null  object
#  1   1       163083 non-null  object
#  2   2       163083 non-null  float64
#  3   3       163083 non-null  float64
#  4   4       163083 non-null  float64
#  5   5       163083 non-null  float64
#  6   6       163083 non-null  int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 8.7+ MB
# None
#                    2              3              4              5         6
# ...
